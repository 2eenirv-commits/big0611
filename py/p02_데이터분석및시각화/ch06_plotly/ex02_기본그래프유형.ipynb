# %% [markdown]
# # 기본 그래프 유형
# ## 선 그래프(line plot)

# %%
import plotly.express as px
import pandas as pd
import numpy as np
np.random.randn(30)
# Out:
# array([ 2.53815352, -0.12063228,  0.10816681, -0.73535455, -1.22402668,
#         1.58007813,  0.18905542, -0.49312063,  0.73502156, -0.26693271,
#        -2.48251551, -1.65806106, -0.01610376, -0.47599234,  0.30306804,
#         0.74306625, -0.94871583,  0.16489904,  0.39174957, -0.61745093,
#         0.42314642, -1.21750161,  1.82212355,  0.04691311, -0.02568721,
#        -0.49230696,  0.38630775,  1.25533995, -0.53606627,  0.52143841])

# %%
# 시계열 데이터 생성
# 2024-01-01 부터 D(Daily) 하루씩 30일간
dates = pd.date_range('2024-01-01', periods=30, freq='D')
# np.random.randn(30): 평균 0, 표준편차 1에 따른 난수 30개
values = np.cumsum(np.random.randn(30)) + 100

time_series = pd.DataFrame({
    '날짜': dates,
    '주가': values
})
time_series
# Out:
#            날짜          주가
# 0  2024-01-01   99.564697
# 1  2024-01-02   99.876352
# 2  2024-01-03   99.635853
# 3  2024-01-04   99.232722
# 4  2024-01-05   99.038952
# 5  2024-01-06   97.907292
# 6  2024-01-07   96.343181
# 7  2024-01-08   96.493569
# 8  2024-01-09   97.166287
# 9  2024-01-10   98.307657
# 10 2024-01-11   96.582167
# 11 2024-01-12   97.895869
# 12 2024-01-13   97.462623
# 13 2024-01-14   95.154113
# 14 2024-01-15   94.229606
# 15 2024-01-16   95.975024
# 16 2024-01-17   96.019632
# 17 2024-01-18   96.722570
# 18 2024-01-19   96.805020
# 19 2024-01-20   98.185701
# 20 2024-01-21   99.730547
# 21 2024-01-22  102.109207
# 22 2024-01-23  102.212723
# 23 2024-01-24  102.296689
# 24 2024-01-25  101.286672
# 25 2024-01-26  102.515100
# 26 2024-01-27  102.493165
# 27 2024-01-28  103.760086
# 28 2024-01-29  103.144417
# 29 2024-01-30  103.108412

# %%
# 1. 단일 선 그래프
fig = px.line(time_series, x='날짜', y='주가',
              title='일별 주가 변동',
              markers=True)
fig.show()

# %%
# 2. 다중 선 그래프
companies = ['삼성전자', 'LG전자', 'SK하이닉스']
stock_data = []

for company in companies:
    for i, date in enumerate(dates):
        price = 100 + np.cumsum(np.random.randn(1))[0] * (i + 1) /10
        stock_data.append({'날짜': date, '회사': company, '주가': price})

df_stocks = pd.DataFrame(stock_data)
df_stocks
# Out:
#            날짜      회사          주가
# 0  2024-01-01    삼성전자  100.018345
# 1  2024-01-02    삼성전자   99.987314
# 2  2024-01-03    삼성전자  100.046691
# 3  2024-01-04    삼성전자  100.185076
# 4  2024-01-05    삼성전자  100.803721
# ..        ...     ...         ...
# 85 2024-01-26  SK하이닉스   99.424168
# 86 2024-01-27  SK하이닉스   97.581545
# 87 2024-01-28  SK하이닉스  105.794496
# 88 2024-01-29  SK하이닉스  104.519288
# 89 2024-01-30  SK하이닉스   99.544308
#
# [90 rows x 3 columns]

# %%
# 데이터 시각화
fig = px.line(df_stocks, 
              x = '날짜', # x축 칼럼명
              y = '주가', # y축 칼럼명
              color='회사', 
              title='회사별 주가 비교',
              line_dash='회사')
fig.show()

# %% [markdown]
# # 산점도(Scatter plot)

# %%
# 1. 기본 산점도
# 키와 몸무게 데이터
height_weight = {
    '키': [160, 165, 170, 175, 180, 162, 168, 172, 178, 185],
    '몸무게': [55, 60, 65, 70, 75, 58, 63, 68, 73, 80],
    '성별': ['여성', '여성', '여성', '남성', '남성', 
           '여성', '여성', '남성', '남성', '남성']
}

df_body = pd.DataFrame(height_weight)
df_body
# Out:
#      키  몸무게  성별
# 0  160   55  여성
# 1  165   60  여성
# 2  170   65  여성
# 3  175   70  남성
# 4  180   75  남성
# 5  162   58  여성
# 6  168   63  여성
# 7  172   68  남성
# 8  178   73  남성
# 9  185   80  남성

# %%
fig = px.scatter(df_body, x='키', y='몸무게',
                     title='키와 몸무게의 관계')
fig.show()
